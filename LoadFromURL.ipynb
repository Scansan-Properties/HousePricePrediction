# %%
pip install regex
# Out:
# ...
# --- Logging error ---
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pip/_internal/utils/logging.py", line 177, in emit
#     self.console.print(renderable, overflow="ignore", crop=False, style=style)
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pip/_vendor/rich/console.py", line 1673, in print
#     extend(render(renderable, render_options))
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pip/_vendor/rich/console.py", line 1305, in render
#     for render_output in iter_render:
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pip/_internal/utils/logging.py", line 134, in __rich_console__
#     for line in lines:
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pip/_vendor/rich/segment.py", line 249, in split_lines
# ...

# %%
import pandas as pd
import regex as reg

# %%
df = pd.read_csv("/Users/khrishawnpowell/Desktop/Projects/Scansan Properties/PricePaid-complete.csv")

# %%
dfNewColumn = data.set_axis(["Unique Transaction Identifier", "Price", "Date of Sale", "Postcode", "Property Type", "Old/New", "Duration of Tenure", "HouseNumber/Name", "Secondary Address", "Street", "Locality", "Town/City", "District", "County", "Price Paid Type", "Record Status " ], axis = 1)

# %%
df = dfNewColumn
df.head()
# Out:
#             Unique Transaction Identifier  Price      Date of Sale  Postcode  \
# 0  {1BA349E3-2579-40D6-999E-49E2A25D2284}  73450  1995-10-09 00:00   L26 7XJ
# 1  {E5B50DCB-BC7A-4E54-B167-49E2A6B4148B}  59000  1995-03-31 00:00  BH12 2AE
# 2  {81E50116-D675-4B7F-9F8D-49E2B5D43271}  31000  1995-12-04 00:00  IP13 0DR
# 3  {B97455B9-75CB-40BB-A615-42C53683E143}  95000  1995-09-22 00:00  WS14 0BE
# 4  {F0D1E8DA-C00D-467A-A41C-42C5378DB6E0}  45450  1995-02-28 00:00   S42 5GA
#
#   Property Type Old/New Duration of Tenure   HouseNumber/Name  \
# 0             D       Y                  F                  6
# 1             D       N                  F                 28
# 2             D       Y                  F    NONSUCH COTTAGE
# 3             D       N                  F  FOX COVER COTTAGE
# 4             S       Y                  F                109
#
#   Secondary Address         Street         Locality     Town/City  \
# ...

# %% [markdown]
# Data Cleaning

# %%
df = df.drop(["Unique Transaction Identifier", "Record Status ", "Price Paid Type"], axis = 1)

# %%
df["Date of Sale"] = df["Date of Sale"].str[:10]

# %%
df.head()
# Out:
#    Price Date of Sale  Postcode Property Type Old/New Duration of Tenure  \
# 0  73450   1995-10-09   L26 7XJ             D       Y                  F
# 1  59000   1995-03-31  BH12 2AE             D       N                  F
# 2  31000   1995-12-04  IP13 0DR             D       Y                  F
# 3  95000   1995-09-22  WS14 0BE             D       N                  F
# 4  45450   1995-02-28   S42 5GA             S       Y                  F
#
#     HouseNumber/Name Secondary Address         Street         Locality  \
# 0                  6               NaN    CATKIN ROAD        LIVERPOOL
# 1                 28               NaN     ALDER ROAD            POOLE
# 2    NONSUCH COTTAGE               NaN     THE STREET        HACHESTON
# 3  FOX COVER COTTAGE               NaN      HALL LANE        LICHFIELD
# 4                109               NaN  ELVASTON ROAD  NORTH WINGFIELD
#
#       Town/City               District         County
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27734965 entries, 0 to 27734964
# Data columns (total 13 columns):
#  #   Column              Dtype
# ---  ------              -----
#  0   Price               int64
#  1   Date of Sale        object
#  2   Postcode            object
#  3   Property Type       object
#  4   Old/New             object
#  5   Duration of Tenure  object
#  6   HouseNumber/Name    object
#  7   Secondary Address   object
#  8   Street              object
#  9   Locality            object
#  10  Town/City           object
#  11  District            object
#  12  County              object
# dtypes: int64(1), object(12)
# memory usage: 2.7+ GB

# %% [markdown]
# **EAST LONDON, England**

# %% [markdown]
# E1 Central East London

# %%
def E1_HeadDistrict(data):
    df2 = data.dropna(subset=["Postcode"])
    pattern = "E1[A-Z].*"
    E1 = data[data.Postcode.str.match(pattern, na=False)]
    return E1

# %%
E1_HeadDistrict(df)
# Out:
#            Price Date of Sale Postcode Property Type Old/New  \
# 2299      195000   1995-03-09  E1W 3TF             F       N
# 15152      82500   1995-01-27  E1W 3ES             F       N
# 15223      80000   1995-09-22  E1W 2JG             F       N
# 15306     171000   1995-09-14  E1W 3NH             F       N
# 15968      91000   1995-12-13  E1W 1UB             F       N
# ...          ...          ...      ...           ...     ...
# 27731416  515000   2022-05-31  E1W 3TB             F       N
# 27732425  850000   2022-09-09  E1W 3TF             F       N
# 27734501  410000   2022-09-23  E1W 3AX             F       N
# 27734544  557000   2022-06-10  E1W 3RY             F       N
# 27734548  735000   2022-02-18  E1W 2JY             F       N
#
#          Duration of Tenure       HouseNumber/Name Secondary Address  \
# 2299                      L        TRAFALGAR COURT           FLAT 52
# 15152                     L  FREE TRADE WHARF, 340           FLAT 60
# ...

# %% [markdown]
# E2 Bethnal

# %%
def E2_BethnalGreen(data):
    df2 = data.dropna(subset=["Postcode"])
    pattern = "E2.*"
    E2 = data[data.Postcode.str.match(pattern, na=False)]
    return E2

# %%
E2_BethnalGreen(df)
# Out:
#            Price Date of Sale Postcode Property Type Old/New  \
# 2874       54000   1995-02-03   E2 6LJ             F       Y
# 5230       86000   1995-03-07   E2 7ED             T       N
# 7729       64995   1995-11-03   E2 6DU             F       Y
# 10359      51995   1995-12-04   E2 6DU             F       Y
# 16659      90000   1995-10-18   E2 9PW             T       N
# ...          ...          ...      ...           ...     ...
# 27732405  945000   2022-08-03  E20 1HQ             T       N
# 27732413  545000   2022-05-30   E2 9BL             F       N
# 27732416  374000   2022-09-09   E2 0SE             F       N
# 27733388  710000   2022-09-01   E2 6QQ             F       N
# 27734524  445000   2022-09-13   E2 9BJ             F       N
#
#          Duration of Tenure     HouseNumber/Name Secondary Address  \
# 2874                      L  ST JAMES COURT, 331            FLAT 3
# 5230                      F                  247               NaN
# ...
