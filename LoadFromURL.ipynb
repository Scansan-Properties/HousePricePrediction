# %%
import pandas as pd
import regex as reg

# %%
# Load in dataset
df = pd.read_csv("/Users/khrishawnpowell/Desktop/Projects/Scansan Properties/PricePaid.csv")

# %% [markdown]
# # 1)Data cleaning

# %%
# Dataset has no headers so have to add them
dfNewColumn = df.set_axis(["UniqueTransactionIdentifier", "Price", "DateOfSale", "Postcode", "PropertyType", "OldNew", "DurationOfTenure", "HouseNumberName", "SecondaryAddress", "Street", "Locality", "TownCity", "District", "County", "PricePaidType", "RecordStatus " ], axis = 1)

# %%
# Assign dataset with new columns to df
df = dfNewColumn
df.head()
# Out:
#               UniqueTransactionIdentifier  Price        DateOfSale  Postcode  \
# 0  {1BA349E3-2579-40D6-999E-49E2A25D2284}  73450  1995-10-09 00:00   L26 7XJ
# 1  {E5B50DCB-BC7A-4E54-B167-49E2A6B4148B}  59000  1995-03-31 00:00  BH12 2AE
# 2  {81E50116-D675-4B7F-9F8D-49E2B5D43271}  31000  1995-12-04 00:00  IP13 0DR
# 3  {B97455B9-75CB-40BB-A615-42C53683E143}  95000  1995-09-22 00:00  WS14 0BE
# 4  {F0D1E8DA-C00D-467A-A41C-42C5378DB6E0}  45450  1995-02-28 00:00   S42 5GA
#
#   PropertyType OldNew DurationOfTenure    HouseNumberName SecondaryAddress  \
# 0            D      Y                F                  6              NaN
# 1            D      N                F                 28              NaN
# 2            D      Y                F    NONSUCH COTTAGE              NaN
# 3            D      N                F  FOX COVER COTTAGE              NaN
# 4            S      Y                F                109              NaN
#
# ...

# %% [markdown]
# Data Cleaning

# %%
# Drop the coluimns not required
df = df.drop(["UniqueTransactionIdentifier", "RecordStatus ", "PricePaidType"], axis = 1)

# %%
df["DateOfSale"] = df["DateOfSale"].str[:10]

# %%
df.head()
# Out:
#    Price  DateOfSale  Postcode PropertyType OldNew DurationOfTenure  \
# 0  73450  1995-10-09   L26 7XJ            D      Y                F
# 1  59000  1995-03-31  BH12 2AE            D      N                F
# 2  31000  1995-12-04  IP13 0DR            D      Y                F
# 3  95000  1995-09-22  WS14 0BE            D      N                F
# 4  45450  1995-02-28   S42 5GA            S      Y                F
#
#      HouseNumberName SecondaryAddress         Street         Locality  \
# 0                  6              NaN    CATKIN ROAD        LIVERPOOL
# 1                 28              NaN     ALDER ROAD            POOLE
# 2    NONSUCH COTTAGE              NaN     THE STREET        HACHESTON
# 3  FOX COVER COTTAGE              NaN      HALL LANE        LICHFIELD
# 4                109              NaN  ELVASTON ROAD  NORTH WINGFIELD
#
#        TownCity               District         County
# 0     LIVERPOOL               KNOWSLEY     MERSEYSIDE
# ...

# %% [markdown]
# *Get Data for London*

# %%
london = df.loc[df["TownCity"] == "LONDON"]
london.District.unique()
# Out:
# array(['LEWISHAM', 'HARINGEY', 'CROYDON', 'BARNET',
#        'KENSINGTON AND CHELSEA', 'TOWER HAMLETS', 'MERTON', 'EALING',
#        'WANDSWORTH', 'HAMMERSMITH AND FULHAM', 'HACKNEY', 'REDBRIDGE',
#        'CITY OF WESTMINSTER', 'ISLINGTON', 'LAMBETH',
#        'RICHMOND UPON THAMES', 'WALTHAM FOREST', 'SOUTHWARK', 'ENFIELD',
#        'GREENWICH', 'BRENT', 'BROMLEY', 'BEXLEY', 'CAMDEN', 'HOUNSLOW',
#        'NEWHAM', 'CITY OF LONDON', 'KINGSTON UPON THAMES',
#        'BARKING AND DAGENHAM', 'MALVERN HILLS', 'EPPING FOREST', 'HARROW',
#        'HAVERING', 'HILLINGDON', 'SUTTON', 'THURROCK',
#        'RHONDDA CYNON TAFF', 'HARLOW', 'CITY OF BRISTOL'], dtype=object)

# %%
london
# Out:
#             Price  DateOfSale  Postcode PropertyType OldNew DurationOfTenure  \
# 46          66500  1995-07-12   SE6 4EW            T      N                F
# 61          67995  1995-09-20   N22 6NP            T      N                F
# 81          77000  1995-07-26  SW16 4QD            T      N                F
# 82          74950  1995-06-29   NW2 2AA            S      N                F
# 106         64000  1995-05-12  SW1X 9PQ            F      N                L
# ...           ...         ...       ...          ...    ...              ...
# 27734550   715000  2022-08-16    N5 2NL            F      N                L
# 27734551  1250000  2022-09-16    W4 2UB            T      N                F
# 27734554   425000  2022-09-16    N9 8BT            S      N                F
# 27734555   392500  2022-09-06    N3 2AA            T      N                L
# 27734556   600000  2022-10-03    N4 1AZ            T      N                L
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27734965 entries, 0 to 27734964
# Data columns (total 13 columns):
#  #   Column            Dtype
# ---  ------            -----
#  0   Price             int64
#  1   DateOfSale        object
#  2   Postcode          object
#  3   PropertyType      object
#  4   OldNew            object
#  5   DurationOfTenure  object
#  6   HouseNumberName   object
#  7   SecondaryAddress  object
#  8   Street            object
#  9   Locality          object
#  10  TownCity          object
#  11  District          object
#  12  County            object
# dtypes: int64(1), object(12)
# memory usage: 2.7+ GB

# %%
# Change dtype
df.Price.astype("int64")
df.DateOfSale.astype("datetime64")
df.PropertyType.astype("category")
df.OldNew.astype("category")
df.District.astype("category")
df.County.astype("category")
# Out:
# 0                                    MERSEYSIDE
# 1                                         POOLE
# 2                                       SUFFOLK
# 3                                 STAFFORDSHIRE
# 4                                    DERBYSHIRE
#                            ...
# 27734960                                 DORSET
# 27734961                                 DORSET
# 27734962                                 DORSET
# 27734963    BOURNEMOUTH, CHRISTCHURCH AND POOLE
# 27734964                                 DORSET
# Name: County, Length: 27734965, dtype: category
# Categories (130, object): ['AVON', 'BATH AND NORTH EAST SOMERSET', 'BEDFORD', 'BEDFORDSHIRE', ..., 'WORCESTERSHIRE', 'WREKIN', 'WREXHAM', 'YORK']

# %% [markdown]
# # 2)Creation of differnt datasets based on district

# %% [markdown]
# **City of London**

# %%
cityoflondon = df.loc[df["District"] == "CITY OF LONDON"]
cityoflondon
# Out:
#             Price  DateOfSale  Postcode PropertyType OldNew DurationOfTenure  \
# 3460       108000  1995-09-01  EC2Y 8BN            F      Y                L
# 6841        90000  1995-01-31  EC2Y 8DN            F      N                L
# 12230      126250  1995-10-27  EC2Y 8BX            F      N                L
# 12626       67000  1995-09-29    E1 8RB            F      N                L
# 13251      830000  1995-01-02  EC4A 1JQ            F      N                F
# ...           ...         ...       ...          ...    ...              ...
# 27721053   685000  2022-08-26  EC2Y 5AG            F      N                L
# 27723976   825000  2022-08-31  EC2Y 8BX            F      N                L
# 27725026   850000  2022-07-07  EC2Y 8AX            F      N                L
# 27732375  1230000  2022-09-16  EC2M 4TR            F      N                L
# 27732432  1137000  2022-10-03  EC2Y 8DN            F      N                L
#
# ...

# %% [markdown]
# **City of Westminister**

# %%
cityOfWestminster = df.loc[df["District"] == "CITY OF WESTMINSTER"]
cityOfWestminster
# Out:
#              Price  DateOfSale  Postcode PropertyType OldNew DurationOfTenure  \
# 322         147000  1995-11-28    W9 2EW            F      N                F
# 429         180000  1995-11-16   NW8 9AA            F      N                L
# 501         136000  1995-05-24    W2 2LP            F      Y                L
# 532         368000  1995-03-09  SW1X 7AR            F      N                L
# 713         693000  1995-06-29   NW1 5HN            F      Y                L
# ...            ...         ...       ...          ...    ...              ...
# 27732577    977500  2022-09-09  SW1V 4QQ            F      N                L
# 27732578   1000000  2022-09-09  SW1V 3QN            F      N                L
# 27732579    600000  2022-09-15    W2 4UJ            F      N                L
# 27734226   6000000  2022-01-31   W1J 8LE            O      N                F
# 27734236  18873116  2022-07-01    W2 3LH            O      N                F
#
# ...

# %% [markdown]
# **Kensington and Chelsea**

# %%
kensingtonAndChelsea = df.loc[df["District"] == "KENSINGTON AND CHELSEA"]
kensingtonAndChelsea
# Out:
#              Price  DateOfSale  Postcode PropertyType OldNew DurationOfTenure  \
# 106          64000  1995-05-12  SW1X 9PQ            F      N                L
# 252         480000  1995-12-15   SW5 9QJ            T      N                F
# 497         112000  1995-01-27   SW5 9TQ            F      N                L
# 678         270000  1995-09-01   SW5 0DU            F      N                L
# 949         150000  1995-05-10   W11 2NH            F      N                L
# ...            ...         ...       ...          ...    ...              ...
# 27733760    720000  2022-09-23   SW5 9EZ            F      N                L
# 27733762    671000  2022-06-08   W11 3QW            F      N                L
# 27734252  10625000  2022-03-01   SW7 2EA            O      N                F
# 27734254  18500000  2022-02-01   SW7 5DJ            T      N                F
# 27734256  10625000  2022-03-01   SW7 2EA            O      N                F
#
# ...

# %% [markdown]
# **Hammersmith and Fulham**

# %%
hammersmithAndFulham = df.loc[df["District"] == "HAMMERSMITH AND FULHAM"]
hammersmithAndFulham
# Out:
#             Price  DateOfSale Postcode PropertyType OldNew DurationOfTenure  \
# 238        137000  1995-09-27  W12 8DW            T      N                F
# 297        112000  1995-01-20  SW6 6PP            F      N                L
# 469        145000  1995-08-01   W6 0BG            S      N                F
# 476        143000  1995-06-30  W14 8QW            F      N                L
# 485         87500  1995-01-20  W14 9JS            F      Y                L
# ...           ...         ...      ...          ...    ...              ...
# 27733765   360000  2022-09-30  W12 8NR            F      N                L
# 27733766   865000  2022-09-29  W12 9BG            T      N                F
# 27734235  1900000  2022-08-01  SW6 1EH            T      N                F
# 27734241   712500  2022-08-09  SW6 7NF            O      N                F
# 27734259  1300000  2022-04-26  W12 9BY            O      N                F
#
# ...

# %% [markdown]
# **Wandsworth**

# %%
wandsworth = df.loc[df["District"] == "WANDSWORTH"]
wandsworth
# Out:
#             Price  DateOfSale  Postcode PropertyType OldNew DurationOfTenure  \
# 231         54000  1995-08-04  SW17 9AJ            F      N                L
# 270         75000  1995-05-10  SW11 3JS            F      N                L
# 400        128500  1995-03-01  SW18 5DH            T      N                F
# 726        130000  1995-07-31  SW18 1HP            T      N                F
# 790        156500  1995-12-07  SW11 1BW            T      N                F
# ...           ...         ...       ...          ...    ...              ...
# 27721810   345000  2022-09-13  SW17 0PP            F      N                L
# 27721819   530000  2022-04-22  SW15 2PW            F      N                L
# 27734247   384000  2022-03-24  SW17 9NA            O      N                L
# 27734250    30000  2022-02-04  SW17 8DL            O      N                F
# 27734253  1160000  2022-08-17  SW12 8HG            O      N                F
#
# ...

# %% [markdown]
# **Lambeth**

# %%
lambeth = df.loc[df["District"] == "LAMBETH"]
lambeth
# Out:
#             Price  DateOfSale  Postcode PropertyType OldNew DurationOfTenure  \
# 408        110995  1995-11-09   SW8 2PH            F      Y                L
# 868         91000  1995-05-24   SW4 0SY            F      Y                L
# 1275        72000  1995-05-15  SE11 6SS            F      N                L
# 1322        77000  1995-03-03   SW9 0NS            F      N                L
# 1421        59950  1995-04-12  SE27 9PJ            T      N                F
# ...           ...         ...       ...          ...    ...              ...
# 27721811   480000  2022-03-29  SW16 5BJ            T      N                F
# 27721812  1865000  2022-08-25   SE1 8YW            F      N                L
# 27721813   325000  2022-08-04   SW2 3LR            O      N                L
# 27734239  1800000  2022-04-06  SW16 3BS            O      N                F
# 27734243   500000  2022-02-07  SW16 5EH            T      N                F
#
# ...

# %% [markdown]
# **Southwark**

# %%
southwark = df.loc[df["District"] == "SOUTHWARK"]
southwark
# Out:
#             Price  DateOfSale  Postcode PropertyType OldNew DurationOfTenure  \
# 554        160000  1995-03-30   SE1 2BB            F      N                L
# 590         66500  1995-09-15  SE15 3LY            T      N                F
# 731         57786  1995-12-21  SE16 3EZ            F      Y                L
# 1159       207800  1995-07-21  SE21 7JN            S      N                F
# 1542        82000  1995-02-10  SE24 9JL            F      N                L
# ...           ...         ...       ...          ...    ...              ...
# 27721603  1175000  2022-04-22   SE1 2ED            F      N                L
# 27721816   387500  2022-05-10  SE15 6ED            F      N                L
# 27734227   560000  2022-02-18   SE1 3UH            O      N                F
# 27734234   840000  2022-02-16  SE15 5JY            D      N                F
# 27734238     4200  2022-05-20  SE15 4HW            O      N                F
#
# ...

# %% [markdown]
# **Tower Hamlets**

# %%
towerhamlets = df.loc[df["District"] == "TOWER HAMLETS"]
towerhamlets
# Out:
#             Price  DateOfSale Postcode PropertyType OldNew DurationOfTenure  \
# 119         54000  1995-02-01   E3 5NF            F      N                L
# 1115       132000  1995-12-11  E14 8EG            F      N                L
# 1216        80000  1995-11-15   E3 4EW            T      N                F
# 2299       195000  1995-03-09  E1W 3TF            F      N                L
# 2566        65000  1995-12-20  E14 3AA            T      N                F
# ...           ...         ...      ...          ...    ...              ...
# 27734530   945000  2022-08-25  E14 3TD            F      N                L
# 27734544   557000  2022-06-10  E1W 3RY            F      N                L
# 27734545  1050000  2022-02-04  E14 9XJ            F      N                L
# 27734546   290000  2022-03-18   E3 3JD            F      N                L
# 27734548   735000  2022-02-18  E1W 2JY            F      N                L
#
# ...

# %% [markdown]
# **Hackney**

# %%
hackney = df.loc[df["District"] == "HACKNEY"]
hackney
# Out:
#             Price  DateOfSale  Postcode PropertyType OldNew DurationOfTenure  \
# 257         62000  1995-08-29    E5 0DP            T      N                F
# 484         65000  1995-02-21    E8 4JJ            S      N                F
# 637        183000  1995-05-30    N1 4HR            S      N                F
# 867        100000  1995-03-06    E5 8NB            T      N                F
# 2122        53000  1995-07-19    E8 3BP            F      N                L
# ...           ...         ...       ...          ...    ...              ...
# 27734517   420000  2022-10-04   N16 7BH            F      N                L
# 27734525   545000  2022-07-29    N4 2WQ            F      N                L
# 27734532  1680000  2022-08-05  EC2A 2FG            F      N                L
# 27734533   830000  2022-09-14    N1 7TX            F      N                L
# 27734537   760000  2022-02-16    E5 9AP            F      N                L
#
# ...

# %% [markdown]
# **Islington**

# %%
islington = df.loc[df["District"] == "ISLINGTON"]
islington
# Out:
#            Price  DateOfSale  Postcode PropertyType OldNew DurationOfTenure  \
# 407       157500  1995-03-17   N19 5EX            S      N                F
# 795       110000  1995-07-14   N19 4PH            F      N                L
# 1195      155000  1995-09-13  EC1V 8BR            F      N                L
# 1471      182500  1995-06-16    N1 2YS            T      N                F
# 1492      115000  1995-08-31    N7 6AA            T      N                F
# ...          ...         ...       ...          ...    ...              ...
# 27734535  355000  2022-09-09    N1 3PP            F      N                L
# 27734536  425000  2022-09-23    N1 8DS            F      N                L
# 27734538  540000  2022-09-14    N1 3NU            F      N                L
# 27734542  470000  2022-09-02    N7 0QH            F      N                L
# 27734550  715000  2022-08-16    N5 2NL            F      N                L
#
# ...

# %% [markdown]
# **Camden**

# %%
camden = df.loc[df["District"] == "CAMDEN"]
camden
# Out:
#              Price  DateOfSale  Postcode PropertyType OldNew DurationOfTenure  \
# 1795         58000  1995-04-05   NW6 3DY            F      N                L
# 1898        167000  1995-07-14   NW5 3HD            T      N                L
# 2449        165000  1995-05-01   NW6 3EE            F      N                L
# 2661         79000  1995-12-15   NW6 2AB            F      N                L
# 2728        375000  1995-09-25   NW1 9NJ            S      N                F
# ...            ...         ...       ...          ...    ...              ...
# 27734230     15000  2022-01-25   NW2 3QG            O      N                F
# 27734231   1325000  2022-05-16   NW5 4HX            O      N                F
# 27734244    985000  2022-07-22  WC1H 9QS            O      N                F
# 27734248     12250  2022-06-29   NW6 1BJ            O      N                F
# 27734257  18000000  2022-01-05   NW6 4JD            O      N                F
#
# ...

# %% [markdown]
# **Brent**

# %%
brent = df.loc[df["District"] == "BRENT"]
brent
# Out:
#             Price  DateOfSale  Postcode PropertyType OldNew DurationOfTenure  \
# 382        118000  1995-07-11   HA9 8NW            S      N                F
# 1030        58031  1995-01-20   NW2 6RW            F      N                L
# 1143        65000  1995-12-14  NW10 5SB            F      N                L
# 1196       123000  1995-08-25   HA9 9JY            D      N                F
# 1832        58100  1995-10-12   NW2 5PJ            S      N                F
# ...           ...         ...       ...          ...    ...              ...
# 27733386  1030000  2022-09-14   NW6 7TU            F      N                L
# 27733541   338000  2022-09-08   NW2 4QA            F      N                L
# 27734492   285000  2022-09-28   NW2 6AD            F      N                L
# 27734515   450000  2022-06-16   NW6 5DQ            F      N                L
# 27734541   522500  2022-06-16   NW2 4JX            F      N                L
#
# ...

# %% [markdown]
# **Ealing**

# %%
ealing = df.loc[df["District"] == "EALING"]
ealing
# Out:
#             Price  DateOfSale Postcode PropertyType OldNew DurationOfTenure  \
# 202        120000  1995-03-17   W3 6JN            T      N                F
# 551         60000  1995-06-26   W3 6BN            F      N                L
# 725        138000  1995-02-24   W5 4UP            T      N                F
# 765         63500  1995-04-03   W7 2PB            F      N                L
# 820        101000  1995-07-14   W7 3DN            T      N                F
# ...           ...         ...      ...          ...    ...              ...
# 27734498   539950  2022-09-09   W3 8AA            F      N                L
# 27734519  1000000  2022-09-29   W5 4HR            T      N                F
# 27734521   799950  2022-09-15   W5 3PL            F      N                L
# 27734523   500000  2022-05-31  W13 0LD            F      N                L
# 27734552   555050  2022-09-26  HA0 1DF            S      N                F
#
# ...

# %% [markdown]
# **Hounslow**

# %%
hounslow = df.loc[df["District"] == "HOUNSLOW"]
hounslow
# Out:
#             Price  DateOfSale  Postcode PropertyType OldNew DurationOfTenure  \
# 528        178294  1995-03-15   TW5 0BY            S      N                F
# 560         61000  1995-06-02   TW7 7EW            S      Y                F
# 562         95000  1995-08-04   TW7 4NP            T      N                F
# 666         69000  1995-08-21   TW3 3SY            S      N                F
# 1021        67500  1995-12-28  TW13 4RY            S      N                F
# ...           ...         ...       ...          ...    ...              ...
# 27734520   730000  2022-09-12   TW7 6PB            S      N                F
# 27734528  1287000  2022-04-29    W4 5SB            T      N                F
# 27734543   635000  2022-09-15    W4 5UG            F      N                L
# 27734551  1250000  2022-09-16    W4 2UB            T      N                F
# 27734557   415000  2022-10-14  TW13 6PG            T      N                F
#
# ...

# %% [markdown]
# **Richmond upon Thames**

# %%
richmondUponThames = df.loc[df["District"] == "RICHMOND UPON THAMES"]
richmondUponThames
# Out:
#             Price  DateOfSale  Postcode PropertyType OldNew DurationOfTenure  \
# 160         79000  1995-08-25   TW2 6EQ            S      N                F
# 508         68000  1995-12-04   TW1 2AU            F      N                L
# 529         68500  1995-10-13  SW13 0EZ            F      N                L
# 604        110000  1995-01-12  TW11 0BS            S      N                F
# 748         88500  1995-02-10   TW1 1JT            F      N                L
# ...           ...         ...       ...          ...    ...              ...
# 27721282   715000  2022-05-20   KT1 4DQ            T      N                F
# 27721296   770000  2022-06-01  TW11 9AB            T      N                F
# 27721303   178500  2022-09-14   TW4 5NS            F      N                L
# 27721598   660000  2022-08-10   TW1 2TE            F      N                L
# 27721808  2300000  2022-05-12  SW14 8TA            O      N                F
#
# ...

# %% [markdown]
# **Kingston Upon Thames**

# %%
kingstonUponThames = df.loc[df["District"] == "KINGSTON UPON THAMES"]
kingstonUponThames
# Out:
#             Price  DateOfSale Postcode PropertyType OldNew DurationOfTenure  \
# 552         65250  1995-07-13  KT6 6AT            F      Y                L
# 576        107950  1995-05-19  KT9 2GD            D      Y                F
# 717         92995  1995-04-26  KT6 5NX            S      Y                F
# 1007       118000  1995-03-13  KT6 7TY            S      N                F
# 1456        59000  1995-11-30  KT2 5NF            T      N                F
# ...           ...         ...      ...          ...    ...              ...
# 27710283   299995  2022-06-01  KT6 7AX            F      N                L
# 27710286  2000000  2022-06-15  KT3 3RN            O      N                F
# 27710297     5000  2022-07-13  KT1 3LU            O      N                L
# 27712090   350000  2022-04-19  KT9 2DT            O      N                F
# 27721597   315000  2022-04-01  KT1 3NG            O      N                F
#
# ...

# %% [markdown]
# **Merton**

# %%
merton = df.loc[df["District"] == "MERTON"]
merton
# Out:
#              Price  DateOfSale  Postcode PropertyType OldNew DurationOfTenure  \
# 178          90000  1995-07-26  SW19 8DT            T      N                F
# 383         139950  1995-07-21  SW19 8BD            T      N                F
# 1674        138000  1995-12-13  SW19 8BU            T      N                F
# 2108         82000  1995-07-21  SW20 8TG            F      N                L
# 2132         77000  1995-06-01  SW19 2DJ            T      N                F
# ...            ...         ...       ...          ...    ...              ...
# 27710294    525000  2022-05-09   CR4 3GA            S      N                F
# 27712096   2870000  2022-03-10  SW19 4QN            O      N                F
# 27716460    500000  2022-06-10   CR4 2EY            T      N                F
# 27721602  38500000  2022-05-13   CR4 2AP            O      N                L
# 27721604    160000  2022-05-06  SW19 8EF            O      N                F
#
# ...

# %% [markdown]
# **Sutton**

# %%
sutton = df.loc[df["District"] == "SUTTON"]
sutton
# Out:
#            Price  DateOfSale Postcode PropertyType OldNew DurationOfTenure  \
# 14         59995  1995-10-19  SM6 7AG            F      Y                L
# 99         75000  1995-01-16  SM3 9UL            S      N                F
# 108        87000  1995-07-28  SM1 3BH            S      N                F
# 483        60000  1995-12-18  SM5 3DY            S      N                F
# 752        85000  1995-04-13  SM5 4LS            T      N                F
# ...          ...         ...      ...          ...    ...              ...
# 27712074  225000  2022-01-21  CR0 4FA            F      N                L
# 27712083  181000  2022-06-28  SM6 7JR            F      N                L
# 27712092   40000  2022-01-21  SM5 3QB            O      N                L
# 27712093  230000  2022-01-31  SM5 3NP            O      N                L
# 27716450  499000  2022-04-28  SM6 8NY            T      N                F
#
# ...

# %% [markdown]
# **Croydon**

# %%
croydon = df.loc[df["District"] == "CROYDON"]
croydon
# Out:
#            Price  DateOfSale  Postcode PropertyType OldNew DurationOfTenure  \
# 81         77000  1995-07-26  SW16 4QD            T      N                F
# 530       130000  1995-07-31   CR2 0RQ            S      N                F
# 719        64000  1995-03-06   CR0 4DB            S      N                F
# 985        69500  1995-09-29   CR0 4UU            T      Y                F
# 991        74000  1995-08-30  SW16 3SJ            T      N                F
# ...          ...         ...       ...          ...    ...              ...
# 27712082  260000  2022-03-04  SE19 3PZ            F      N                L
# 27712084  210000  2022-05-26  SE19 3EQ            F      N                L
# 27712085  407754  2022-04-01  SE19 3UX            F      N                L
# 27712095  440000  2022-03-21   CR5 2LA            F      N                L
# 27716458  395000  2022-04-11  SE19 3DE            T      N                F
#
# ...

# %% [markdown]
# **Bromley**

# %%
bromley = df.loc[df["District"] == "BROMLEY"]
bromley
# Out:
#             Price  DateOfSale  Postcode PropertyType OldNew DurationOfTenure  \
# 64          80000  1995-06-01   BR3 3QG            T      N                F
# 240         81000  1995-03-09   BR2 7JQ            S      N                F
# 874         68000  1995-05-31   BR1 3PG            F      N                L
# 1004       115000  1995-01-20   BR5 1JX            S      N                F
# 1181       150000  1995-04-28   BR1 3DR            D      N                F
# ...           ...         ...       ...          ...    ...              ...
# 27714769   490000  2022-06-30   BR5 2BG            T      N                F
# 27714785   845000  2022-07-29   BR7 6NX            D      N                F
# 27714793   515000  2022-08-04   BR6 9RR            S      N                F
# 27715115  1428000  2022-09-09  SE26 6HH            D      N                F
# 27718908   915000  2022-01-14   BR2 9PU            D      N                F
#
# ...

# %% [markdown]
# **Lewisham**

# %%
lewisham = df.loc[df["District"] == "LEWISHAM"]
lewisham
# Out:
#            Price  DateOfSale  Postcode PropertyType OldNew DurationOfTenure  \
# 46         66500  1995-07-12   SE6 4EW            T      N                F
# 598       200500  1995-11-20  SE23 2QA            D      N                F
# 1128       59500  1995-11-21  SE12 8RF            F      N                L
# 1501       68750  1995-07-28  SE23 1QJ            F      Y                L
# 1764       72500  1995-04-24  SE23 1NQ            T      N                F
# ...          ...         ...       ...          ...    ...              ...
# 27721821  265000  2022-08-19  SE13 6HX            F      N                L
# 27721822  204000  2022-04-01  SE26 5RT            F      N                L
# 27734237  815000  2022-07-04  SE26 4QJ            O      N                F
# 27734245  200000  2022-08-11  SE13 7JD            T      N                F
# 27734255  640000  2022-01-14  SE26 4LP            S      N                F
#
# ...

# %% [markdown]
# **Greenwich**

# %%
greenwich = df.loc[df["District"] == "GREENWICH"]
greenwich
# Out:
#             Price  DateOfSale  Postcode PropertyType OldNew DurationOfTenure  \
# 647         87950  1995-11-30  SE18 4PR            F      N                L
# 1058       162000  1995-06-30   SE3 0AA            F      N                L
# 1942        89950  1995-03-01   SE3 7QG            F      N                L
# 2069        51000  1995-12-06   SE9 6NY            S      N                F
# 2194        53995  1995-02-07   SE7 7UD            F      Y                L
# ...           ...         ...       ...          ...    ...              ...
# 27721820   340000  2022-08-17  SE18 1SF            T      N                F
# 27734229  1650000  2022-05-17   SE9 1TD            O      N                F
# 27734246   436500  2022-09-02  SE18 7DY            O      N                F
# 27734249   305000  2022-08-12  SE18 7PT            T      N                F
# 27734251   400000  2022-05-05  SE18 1HF            O      N                F
#
# ...

# %% [markdown]
# **Bexley**

# %%
bexley = df.loc[df["District"] == "BEXLEY"]
bexley
# Out:
#            Price  DateOfSale  Postcode PropertyType OldNew DurationOfTenure  \
# 729        67995  1995-04-21   DA7 4BW            T      N                F
# 732        76000  1995-03-10   DA6 8BN            F      N                L
# 786        68500  1995-07-21  DA16 3JQ            S      N                F
# 789        85500  1995-12-12  DA14 5LT            D      N                F
# 960        67000  1995-10-02  DA14 6PN            T      N                F
# ...          ...         ...       ...          ...    ...              ...
# 27712764  452000  2022-08-23   DA1 3NR            S      N                F
# 27714755  420000  2022-05-13   DA7 5RU            S      N                F
# 27714762  422000  2022-05-20  DA16 2DU            S      N                F
# 27714779  395000  2022-07-26   DA8 1AJ            S      N                F
# 27715180  550000  2022-08-09   DA8 1LR            T      N                F
#
# ...

# %% [markdown]
# **Havering**

# %%
havering = df.loc[df["District"] == "HAVERING"]
havering
# Out:
#            Price  DateOfSale  Postcode PropertyType OldNew DurationOfTenure  \
# 42         84000  1995-07-28   RM5 3YL            T      N                F
# 95         56000  1995-02-24   RM1 2DX            T      N                F
# 366        68000  1995-04-10   RM5 3XS            S      N                F
# 377        60000  1995-02-03  RM13 9LD            S      N                F
# 980        54000  1995-12-21   RM3 7HP            T      N                F
# ...          ...         ...       ...          ...    ...              ...
# 27733738  260000  2022-10-03  RM11 3UL            S      N                L
# 27733746  701000  2022-09-16  RM11 1LB            D      N                F
# 27733751  445000  2022-07-22   RM1 2BT            T      N                F
# 27733763  215000  2022-09-09  RM12 5NJ            F      N                L
# 27733764  225000  2022-02-25   RM7 0FA            F      N                L
#
# ...

# %% [markdown]
# **Barking and Dagenham**

# %%
barkingAndDagenham = df.loc[df["District"] == "BARKING AND DAGENHAM"]
barkingAndDagenham
# Out:
#            Price  DateOfSale  Postcode PropertyType OldNew DurationOfTenure  \
# 1332       73500  1995-12-08  IG11 0XG            S      Y                F
# 2344       83500  1995-06-12   RM6 6AB            T      N                F
# 3176       57000  1995-09-15   RM8 2BH            S      N                F
# 4447       53000  1995-06-30  RM10 8UE            F      Y                L
# 6979       50750  1995-09-08  IG11 9EN            F      N                L
# ...          ...         ...       ...          ...    ...              ...
# 27721896  353000  2022-10-06  IG11 0LA            T      N                F
# 27721897  370000  2022-03-25   RM9 4PJ            T      N                F
# 27722002  426000  2022-09-16   RM8 2SU            S      N                F
# 27722003  490000  2022-10-03  RM10 7UH            S      N                F
# 27722124  257000  2022-09-02   RM9 4PQ            F      N                L
#
# ...

# %% [markdown]
# **Redbridge**

# %%
redbridge = df.loc[df["District"] == "REDBRIDGE"]
redbridge
# Out:
#             Price  DateOfSale  Postcode PropertyType OldNew DurationOfTenure  \
# 170         73000  1995-02-03   IG1 3QJ            T      N                F
# 278         68500  1995-10-02   RM6 4PD            T      N                F
# 306         93000  1995-11-13   E12 5EF            T      N                F
# 516         75500  1995-09-01   IG3 8QW            T      N                F
# 745         50500  1995-07-28   IG2 7SF            F      N                L
# ...           ...         ...       ...          ...    ...              ...
# 27729494  1650000  2022-09-28   E11 2JU            S      N                F
# 27729495   488000  2022-06-01   IG5 0NB            S      N                F
# 27733747   257000  2022-08-31  IG11 9BZ            F      N                L
# 27733748   215000  2022-09-29   IG3 9RJ            F      N                L
# 27733761   325000  2022-10-04   IG6 3EA            F      N                L
#
# ...

# %% [markdown]
# **Newham**

# %%
newham = df.loc[df["District"] == "NEWHAM"]
newham
# Out:
#            Price  DateOfSale Postcode PropertyType OldNew DurationOfTenure  \
# 2413       82500  1995-08-09   E6 5YE            T      N                F
# 2829       53000  1995-11-06  E15 3AR            F      Y                L
# 5313       56500  1995-10-06  E16 3NJ            T      N                F
# 5413       77000  1995-10-26  E15 1JJ            T      N                F
# 5671       57150  1995-04-27   E7 8HN            T      N                F
# ...          ...         ...      ...          ...    ...              ...
# 27722139  365000  2022-09-21   E7 9NP            F      N                L
# 27722147  325940  2022-09-30  E15 4QR            F      N                L
# 27722149  480000  2022-06-29  E16 1BA            F      N                L
# 27722151  470000  2022-08-16  E13 8RX            T      N                F
# 27722152  240000  2022-08-30  E16 1BE            F      N                L
#
#              HouseNumberName SecondaryAddress              Street  \
# ...

# %% [markdown]
# **Waltham Forest**

# %%
walthamForest = df.loc[df["District"] == "WALTHAM FOREST"]
walthamForest
# Out:
#             Price  DateOfSale Postcode PropertyType OldNew DurationOfTenure  \
# 546         60000  1995-12-18  E17 6RD            T      N                F
# 1452        54000  1995-08-18  E10 5DH            T      N                F
# 2098        55950  1995-05-19  E17 5LR            S      N                F
# 2123        58000  1995-01-31  E10 5LT            T      N                F
# 2913        71000  1995-06-09  E17 3PG            S      N                F
# ...           ...         ...      ...          ...    ...              ...
# 27733536   395000  2022-08-18  E10 5ET            F      N                L
# 27733538  1087000  2022-09-15  E17 4SN            T      N                F
# 27733539  1095000  2022-10-03  E17 4SN            T      N                F
# 27734511   487000  2022-09-20  E17 5HA            F      N                L
# 27734540   525000  2022-08-04  E17 5QH            T      N                F
#
# ...

# %% [markdown]
# **Haringey**

# %%
haringey = df.loc[df["District"] == "HARINGEY"]
haringey
# Out:
#            Price  DateOfSale Postcode PropertyType OldNew DurationOfTenure  \
# 61         67995  1995-09-20  N22 6NP            T      N                F
# 197       243000  1995-06-30   N8 9AU            T      N                F
# 706        64000  1995-07-31  N15 6JT            T      N                F
# 730       425000  1995-07-27   N6 4RA            S      N                F
# 836        80000  1995-11-27  N17 6UR            T      N                F
# ...          ...         ...      ...          ...    ...              ...
# 27734516  346400  2022-09-30   N4 4QJ            F      N                L
# 27734518  230000  2022-09-23  N22 5JH            F      N                L
# 27734529  314000  2022-06-07  N15 4DR            F      N                L
# 27734539  385000  2022-09-01   N4 4JL            F      N                L
# 27734556  600000  2022-10-03   N4 1AZ            T      N                L
#
#           HouseNumberName SecondaryAddress               Street  \
# ...

# %% [markdown]
# **Enfield**

# %%
enfield = df.loc[df["District"] == "ENFIELD"]
enfield
# Out:
#            Price  DateOfSale Postcode PropertyType OldNew DurationOfTenure  \
# 587        60000  1995-03-06  N21 1QE            F      N                L
# 702       110000  1995-01-31  N21 3DU            T      N                F
# 1250       79000  1995-09-20  EN1 1NX            T      N                F
# 1519       71000  1995-03-31  N22 8NN            F      N                L
# 1634       80000  1995-01-27  N18 1AW            T      N                F
# ...          ...         ...      ...          ...    ...              ...
# 27733407  555000  2022-09-02  N21 3JX            S      N                L
# 27733525  525000  2022-02-18  N11 1QH            F      N                L
# 27733542  290000  2022-10-04  EN3 7HL            F      N                L
# 27734553  225000  2022-10-06  EN2 0TF            F      N                L
# 27734554  425000  2022-09-16   N9 8BT            S      N                F
#
# ...

# %% [markdown]
# **Barnet**

# %%
barnet = df.loc[df["District"] == "BARNET"]
barnet
# Out:
#             Price  DateOfSale Postcode PropertyType OldNew DurationOfTenure  \
# 82          74950  1995-06-29  NW2 2AA            S      N                F
# 352         63000  1995-11-24  N11 1JS            T      N                F
# 398        121250  1995-05-19  N12 8LR            F      N                L
# 461         90000  1995-09-22  N12 9EA            T      N                F
# 617         66500  1995-07-28  HA8 0DZ            S      N                F
# ...           ...         ...      ...          ...    ...              ...
# 27733532   600000  2022-09-16  N12 9ET            F      N                L
# 27734495   558000  2022-09-20  NW2 3LL            F      N                L
# 27734534   340000  2022-09-20  NW7 3HR            F      N                L
# 27734547  1150000  2022-09-16  N10 1HG            T      N                F
# 27734555   392500  2022-09-06   N3 2AA            T      N                L
#
# ...

# %% [markdown]
# **Barnet**

# %%
barnet = df.loc[df["District"] == "BARNET"]
barnet
# Out:
#             Price  DateOfSale Postcode PropertyType OldNew DurationOfTenure  \
# 82          74950  1995-06-29  NW2 2AA            S      N                F
# 352         63000  1995-11-24  N11 1JS            T      N                F
# 398        121250  1995-05-19  N12 8LR            F      N                L
# 461         90000  1995-09-22  N12 9EA            T      N                F
# 617         66500  1995-07-28  HA8 0DZ            S      N                F
# ...           ...         ...      ...          ...    ...              ...
# 27733532   600000  2022-09-16  N12 9ET            F      N                L
# 27734495   558000  2022-09-20  NW2 3LL            F      N                L
# 27734534   340000  2022-09-20  NW7 3HR            F      N                L
# 27734547  1150000  2022-09-16  N10 1HG            T      N                F
# 27734555   392500  2022-09-06   N3 2AA            T      N                L
#
# ...

# %% [markdown]
# **Harrow**

# %%
harrow = df.loc[df["District"] == "HARROW"]
harrow
# Out:
#            Price  DateOfSale Postcode PropertyType OldNew DurationOfTenure  \
# 35        292500  1995-08-31  HA3 6DD            D      Y                F
# 112        82950  1995-06-23  HA2 6NH            S      N                F
# 744        73000  1995-11-30  HA3 9HR            S      N                F
# 1025       58000  1995-01-31  HA3 7SN            T      N                F
# 1158       88950  1995-03-10  HA5 3PR            F      Y                L
# ...          ...         ...      ...          ...    ...              ...
# 27733514  345000  2022-08-17  HA2 0NB            F      N                L
# 27733528  400000  2022-09-30  HA1 1SA            F      N                L
# 27734494  325000  2022-09-23  HA7 4ND            F      N                L
# 27734522  305000  2022-09-26  HA7 2SR            F      N                L
# 27734549  551000  2022-09-30  HA5 3LA            F      N                L
#
# ...

# %% [markdown]
# **Hillingdon**

# %%
hillingdon = df.loc[df["District"] == "HILLINGDON"]
hillingdon
# Out:
#            Price  DateOfSale Postcode PropertyType OldNew DurationOfTenure  \
# 188        51000  1995-12-21  UB8 2UW            F      N                L
# 194        82500  1995-02-17  UB4 9TH            S      Y                F
# 447       124500  1995-04-11  UB8 3AL            S      N                F
# 583       125000  1995-09-08  UB4 8NX            D      N                F
# 733       156250  1995-07-27  UB8 2PS            D      N                F
# ...          ...         ...      ...          ...    ...              ...
# 27734506  470000  2022-10-07  UB4 9HU            T      N                F
# 27734507  135000  2022-07-05  HA4 8FX            F      N                L
# 27734514  355000  2022-09-30  UB9 6HD            F      N                L
# 27734526  328000  2022-09-01  HA4 8FA            F      N                L
# 27734531  305000  2022-08-04  HA6 2NQ            F      N                L
#
# ...

# %% [markdown]
# # 3)Data Exploration

# %% [markdown]
# **EAST LONDON, England**

# %% [markdown]
# E1 Central East London

# %%
# BY POSTCODE_TYPE
def E1_HeadDistrict(data):
    df2 = data.dropna(subset=["Postcode"])
    pattern1 = "E1[A-Z].*"
    pattern2 = "E1 [1-9].*"
    E1Char = data[data.Postcode.str.match(pattern1, na=False)]
    E1Num = data[data.Postcode.str.match(pattern2, na=False)]
    E1 = pd.concat([E1Char, E1Num], axis=0)
    
    
    return E1

# %%
E1_HeadDistrict(df)
# Out:
#            Price Date of Sale Postcode Property Type Old/New  \
# 2299      195000   1995-03-09  E1W 3TF             F       N
# 15152      82500   1995-01-27  E1W 3ES             F       N
# 15223      80000   1995-09-22  E1W 2JG             F       N
# 15306     171000   1995-09-14  E1W 3NH             F       N
# 15968      91000   1995-12-13  E1W 1UB             F       N
# ...          ...          ...      ...           ...     ...
# 27732407  870000   2022-09-15   E1 1PT             F       N
# 27733400  352500   2022-08-19   E1 3BD             F       N
# 27734502  600000   2022-09-30   E1 6JB             F       N
# 27734503  425000   2022-09-27   E1 3JH             F       N
# 27734510  570000   2022-09-09   E1 6HF             F       N
#
#          Duration of Tenure       HouseNumber/Name Secondary Address  \
# 2299                      L        TRAFALGAR COURT           FLAT 52
# 15152                     L  FREE TRADE WHARF, 340           FLAT 60
# ...

# %% [markdown]
# E2 Bethnal

# %%
def E2_BethnalGreen(data):
    df2 = data.dropna(subset=["Postcode"])
    pattern = "E2.*"
    E2 = data[data.Postcode.str.match(pattern, na=False)]
    return E2

# %%
E2_BethnalGreen(df)
# Out:
#            Price Date of Sale Postcode Property Type Old/New  \
# 2874       54000   1995-02-03   E2 6LJ             F       Y
# 5230       86000   1995-03-07   E2 7ED             T       N
# 7729       64995   1995-11-03   E2 6DU             F       Y
# 10359      51995   1995-12-04   E2 6DU             F       Y
# 16659      90000   1995-10-18   E2 9PW             T       N
# ...          ...          ...      ...           ...     ...
# 27732405  945000   2022-08-03  E20 1HQ             T       N
# 27732413  545000   2022-05-30   E2 9BL             F       N
# 27732416  374000   2022-09-09   E2 0SE             F       N
# 27733388  710000   2022-09-01   E2 6QQ             F       N
# 27734524  445000   2022-09-13   E2 9BJ             F       N
#
#          Duration of Tenure     HouseNumber/Name Secondary Address  \
# 2874                      L  ST JAMES COURT, 331            FLAT 3
# 5230                      F                  247               NaN
# ...

# %%
brent = df.loc[df["District"] == "BRENT"]
brent
